# %%
import pandas as pd
import numpy as np

# %%
df_defect_rate = pd.read_csv("../Masked_Renamed_Factory_Sample/Defect Rates.csv")
df_step1_terminal = pd.read_csv("../Masked_Renamed_Factory_Sample/Step1_Mount_Terminals.csv")
df_step1_resin = pd.read_csv("../Masked_Renamed_Factory_Sample/Step1_Mount_Terminal_Resin.csv")
df_step2_wind_wire = pd.read_csv("../Masked_Renamed_Factory_Sample/Step2_Wind_Wire.csv")
df_step3_peel_wire = pd.read_csv("../Masked_Renamed_Factory_Sample/Step3_Peel_Wire.csv")
df_step4_check_alignment = pd.read_csv("../Masked_Renamed_Factory_Sample/Step4_Check_Alignment.csv")

# %%
print(df_defect_rate.shape)
print(df_step1_terminal.shape)
print(df_step1_resin.shape)
print(df_step2_wind_wire.shape)
print(df_step3_peel_wire.shape)
print(df_step4_check_alignment.shape)
# Out:
# (10000, 3)
# (10000, 33)
# (10000, 15)
# (10000, 19)
# (10000, 20)
# (10000, 55)

# %%
print(df_defect_rate.isnull().sum())
print(" ")
print(df_step1_terminal.isnull().sum())

print(" ")
print(df_step1_resin.isnull().sum())
print(" ")

print(df_step2_wind_wire.isnull().sum())
print(" ")
print(df_step3_peel_wire.isnull().sum())
print(" ")
print(df_step4_check_alignment.isnull().sum())
# Out:
# Date           0
# Time           0
# Defect Rate    0
# dtype: int64
#
# DateTime                           0
# Time                               0
# MeasurementCount                   0
# OverallJudgment                    0
# Trg1OverallJudgment                0
# Trg1NGItem                         0
# Trg1PitchUpper                     0
# Trg1PitchLower                     0
# Trg1PitchLeft                      0
# Trg1PitchRight                     0
# Trg1TerminalThetaCheckArea1        0
# Trg1TerminalThetaCheckArea2        0
# Trg1TerminalThetaCheckArea3        0
# Trg1TerminalThetaCheckArea4        0
# Trg1Terminal1CoreCenterDistance    0
# Trg1Terminal2CoreCenterDistance    0
# Trg1Terminal3CoreCenterDistance    0
# Trg1Terminal4CoreCenterDistance    0
# Trg2OverallJudgment                0
# Trg2NGItem                         0
# Trg2PitchUpper                     0
# Trg2PitchLower                     0
# Trg2PitchLeft                      0
# Trg2PitchRight                     0
# Trg2TerminalThetaCheckArea1        0
# Trg2TerminalThetaCheckArea2        0
# Trg2TerminalThetaCheckArea3        0
# Trg2TerminalThetaCheckArea4        0
# Trg2Terminal1CoreCenterDistance    0
# Trg2Terminal2CoreCenterDistance    0
# Trg2Terminal3CoreCenterDistance    0
# Trg2Terminal4CoreCenterDistance    0
# OutputBufferMargin                 0
# dtype: int64
#
# DateTime                 0
# Time                     0
# MeasurementCount         0
# OverallJudgment          0
# Cam1TerminalNo           0
# Cam1Judgment             0
# Cam1NGItem               0
# Cam1LeftTerminalArea     0
# Cam1RightTerminalArea    0
# Cam2TerminalNo           0
# Cam2Judgment             0
# Cam2NGItem               0
# Cam2LeftTerminalArea     0
# Cam2RightTerminalArea    0
# OutputBufferMargin       0
# dtype: int64
#
# DateTime              0
# Time                  0
# MeasurementCount      0
# OverallJudgment       0
# SP_No                 0
# SP_Side               0
# S1X                   0
# S1Y                   0
# S1L                   0
# S2X                   0
# S2Y                   0
# S2L                   0
# F1X                   0
# F1Y                   0
# F1L                   0
# F2X                   0
# F2Y                   0
# F2L                   0
# OutputBufferMargin    0
# dtype: int64
#
# DateTime                0
# Time                    0
# MeasurementCount        0
# OverallJudgment         0
# #d1                     0
# #d2                     0
# Judgment1               0
# Judgment2               0
# Judgment3               0
# Judgment4               0
# WireLength              0
# WireWidth               0
# TerminalWidth           0
# WireTerminalDistance    0
# WireAngle               0
# InspectionArea          0
# UnpeeledArea            0
# #go                     0
# #auto                   0
# OutputBufferMargin      0
# dtype: int64
#
# DateTime                                         0
# Time                                             0
# MeasurementCount                                 0
# OverallJudgment                                  0
# Alarm_No                                         0
# LowerLeft_MoveDistanceX                          0
# LowerLeft_MoveDistanceY                          0
# LowerLeft_WireDisplacement                       0
# LowerLeft_WireCenter_IrradiationPosition         0
# LowerLeft_WireWidth                              0
# LowerLeft_WireLength                             0
# LowerLeft_WireFittingDistance                    0
# LowerLeft_FittingSearchHeight                    0
# LowerLeft_CameraCenter_IrradiationDistanceX      0
# LowerLeft_CameraCenter_IrradiationDistanceY      0
# LowerLeft_ProductCenter_IrradiationDistanceX     0
# LowerLeft_ProductCenter_IrradiationDistanceY     0
# UpperLeft_MoveDistanceX                          0
# UpperLeft_MoveDistanceY                          0
# UpperLeft_WireDisplacement                       0
# UpperLeft_WireCenter_IrradiationPosition         0
# UpperLeft_WireWidth                              0
# UpperLeft_WireLength                             0
# UpperLeft_WireFittingDistance                    0
# UpperLeft_FittingSearchHeight                    0
# UpperLeft_CameraCenter_IrradiationDistanceX      0
# UpperLeft_CameraCenter_IrradiationDistanceY      0
# UpperLeft_ProductCenter_IrradiationDistanceX     0
# UpperLeft_ProductCenter_IrradiationDistanceY     0
# UpperRight_MoveDistanceX                         0
# UpperRight_MoveDistanceY                         0
# UpperRight_WireDisplacement                      0
# UpperRight_WireCenter_IrradiationPosition        0
# UpperRight_WireWidth                             0
# UpperRight_WireLength                            0
# UpperRight_WireFittingDistance                   0
# UpperRight_FittingSearchHeight                   0
# UpperRight_CameraCenter_IrradiationDistanceX     0
# UpperRight_CameraCenter_IrradiationDistanceY     0
# UpperRight_ProductCenter_IrradiationDistanceX    0
# UpperRight_ProductCenter_IrradiationDistanceY    0
# LowerRight_MoveDistanceX                         0
# LowerRight_MoveDistanceY                         0
# LowerRight_WireDisplacement                      0
# LowerRight_WireCenter_IrradiationPosition        0
# LowerRight_WireWidth                             0
# LowerRight_WireLength                            0
# LowerRight_WireFittingDistance                   0
# LowerRight_FittingSearchHeight                   0
# LowerRight_CameraCenter_IrradiationDistanceX     0
# LowerRight_CameraCenter_IrradiationDistanceY     0
# LowerRight_ProductCenter_IrradiationDistanceX    0
# LowerRight_ProductCenter_IrradiationDistanceY    0
# InspectionExecutionID                            0
# OutputBufferMargin                               0
# dtype: int64

# %% [markdown]
# - We observer that there no missing value in the dataset

# %%
print(df_defect_rate.nunique())
print(" ")
print(df_step1_terminal.nunique())

print(" ")
print(df_step1_resin.nunique())
print(" ")

print(df_step2_wind_wire.nunique())
print(" ")
print(df_step3_peel_wire.nunique())
print(" ")
print(df_step4_check_alignment.nunique())
# Out:
# Date              1
# Time           9309
# Defect Rate      11
# dtype: int64
#
# DateTime                               1
# Time                                3548
# MeasurementCount                   10000
# OverallJudgment                        2
# Trg1OverallJudgment                    1
# Trg1NGItem                             1
# Trg1PitchUpper                      1955
# Trg1PitchLower                      2154
# Trg1PitchLeft                       1740
# Trg1PitchRight                      1267
# Trg1TerminalThetaCheckArea1           56
# Trg1TerminalThetaCheckArea2           65
# Trg1TerminalThetaCheckArea3           67
# Trg1TerminalThetaCheckArea4           58
# Trg1Terminal1CoreCenterDistance     2881
# Trg1Terminal2CoreCenterDistance     2775
# Trg1Terminal3CoreCenterDistance     3036
# Trg1Terminal4CoreCenterDistance     2507
# Trg2OverallJudgment                    2
# Trg2NGItem                             1
# Trg2PitchUpper                      2007
# Trg2PitchLower                      1913
# Trg2PitchLeft                       1906
# Trg2PitchRight                      1431
# Trg2TerminalThetaCheckArea1           57
# Trg2TerminalThetaCheckArea2           66
# Trg2TerminalThetaCheckArea3           68
# Trg2TerminalThetaCheckArea4           58
# Trg2Terminal1CoreCenterDistance     3379
# Trg2Terminal2CoreCenterDistance     2762
# Trg2Terminal3CoreCenterDistance     2716
# Trg2Terminal4CoreCenterDistance     2333
# OutputBufferMargin                     1
# dtype: int64
#
# DateTime                     1
# Time                      3600
# MeasurementCount         10000
# OverallJudgment              2
# Cam1TerminalNo               1
# Cam1Judgment                 1
# Cam1NGItem                   1
# Cam1LeftTerminalArea      9999
# Cam1RightTerminalArea     9997
# Cam2TerminalNo               1
# Cam2Judgment                 1
# Cam2NGItem                   2
# Cam2LeftTerminalArea      9997
# Cam2RightTerminalArea     9997
# OutputBufferMargin           1
# dtype: int64
#
# DateTime                  1
# Time                    928
# MeasurementCount      10000
# OverallJudgment           1
# SP_No                    12
# SP_Side                   2
# S1X                    3871
# S1Y                    3643
# S1L                    3793
# S2X                    4195
# S2Y                    6051
# S2L                    4133
# F1X                    5452
# F1Y                    6199
# F1L                    5448
# F2X                    5484
# F2Y                    6203
# F2L                    5497
# OutputBufferMargin        1
# dtype: int64
#
# DateTime                    1
# Time                     1386
# MeasurementCount        10000
# OverallJudgment             2
# #d1                         1
# #d2                         1
# Judgment1                   2
# Judgment2                   1
# Judgment3                   1
# Judgment4                   2
# WireLength               3290
# WireWidth                  12
# TerminalWidth              24
# WireTerminalDistance       96
# WireAngle                2306
# InspectionArea            267
# UnpeeledArea               77
# #go                         4
# #auto                       2
# OutputBufferMargin          1
# dtype: int64
#
# DateTime                                             1
# Time                                              3600
# MeasurementCount                                 10000
# OverallJudgment                                      1
# Alarm_No                                             1
# LowerLeft_MoveDistanceX                            309
# LowerLeft_MoveDistanceY                              8
# LowerLeft_WireDisplacement                         358
# LowerLeft_WireCenter_IrradiationPosition           358
# LowerLeft_WireWidth                                149
# LowerLeft_WireLength                                12
# LowerLeft_WireFittingDistance                        4
# LowerLeft_FittingSearchHeight                        7
# LowerLeft_CameraCenter_IrradiationDistanceX        309
# LowerLeft_CameraCenter_IrradiationDistanceY          8
# LowerLeft_ProductCenter_IrradiationDistanceX      2209
# LowerLeft_ProductCenter_IrradiationDistanceY      3334
# UpperLeft_MoveDistanceX                            355
# UpperLeft_MoveDistanceY                              8
# UpperLeft_WireDisplacement                         373
# UpperLeft_WireCenter_IrradiationPosition           373
# UpperLeft_WireWidth                                146
# UpperLeft_WireLength                                14
# UpperLeft_WireFittingDistance                        3
# UpperLeft_FittingSearchHeight                        7
# UpperLeft_CameraCenter_IrradiationDistanceX        355
# UpperLeft_CameraCenter_IrradiationDistanceY          8
# UpperLeft_ProductCenter_IrradiationDistanceX      2153
# UpperLeft_ProductCenter_IrradiationDistanceY      3408
# UpperRight_MoveDistanceX                           278
# UpperRight_MoveDistanceY                            15
# UpperRight_WireDisplacement                        445
# UpperRight_WireCenter_IrradiationPosition          446
# UpperRight_WireWidth                               366
# UpperRight_WireLength                               24
# UpperRight_WireFittingDistance                       7
# UpperRight_FittingSearchHeight                      13
# UpperRight_CameraCenter_IrradiationDistanceX       278
# UpperRight_CameraCenter_IrradiationDistanceY        15
# UpperRight_ProductCenter_IrradiationDistanceX     3542
# UpperRight_ProductCenter_IrradiationDistanceY     3552
# LowerRight_MoveDistanceX                           302
# LowerRight_MoveDistanceY                            14
# LowerRight_WireDisplacement                        678
# LowerRight_WireCenter_IrradiationPosition          678
# LowerRight_WireWidth                               466
# LowerRight_WireLength                               23
# LowerRight_WireFittingDistance                       7
# LowerRight_FittingSearchHeight                      11
# LowerRight_CameraCenter_IrradiationDistanceX       302
# LowerRight_CameraCenter_IrradiationDistanceY        14
# LowerRight_ProductCenter_IrradiationDistanceX     3451
# LowerRight_ProductCenter_IrradiationDistanceY     4515
# InspectionExecutionID                                2
# OutputBufferMargin                                   1
# dtype: int64

# %% [markdown]
# - Observe the measurement column has unique in dataset

# %%
df_step1_resin[["DateTime",'Time',"MeasurementCount"]].sort_values("MeasurementCount",ascending=True)[20:40]
# Out:
#         DateTime     Time  MeasurementCount
# 9979  29/08/2024  26:06.0           3003831
# 9978  29/08/2024  26:07.0           3003832
# 9977  29/08/2024  26:08.0           3003833
# 9976  29/08/2024  26:09.0           3003834
# 9975  29/08/2024  26:10.0           3003835
# 9974  29/08/2024  26:11.0           3003836
# 9973  29/08/2024  26:11.0           3003837
# 9972  29/08/2024  26:12.0           3003838
# 9971  29/08/2024  26:13.0           3003839
# 9970  29/08/2024  26:14.0           3003840
# 9969  29/08/2024  26:15.0           3003841
# 9968  29/08/2024  26:16.0           3003842
# 9967  29/08/2024  26:16.0           3003843
# 9966  29/08/2024  26:17.0           3003844
# 9965  29/08/2024  26:18.0           3003845
# 9964  29/08/2024  26:19.0           3003846
# 9963  29/08/2024  26:20.0           3003847
# 9962  29/08/2024  26:21.0           3003848
# 9961  29/08/2024  26:22.0           3003849
# 9960  29/08/2024  26:22.0           3003850

# %% [markdown]
# - we can observe that MeasurementCount increase with time
# - data is at model second level for each minutes
# - time column dosen't have Hour

# %%
df=df_defect_rate[::-1].reset_index(drop=True)
# Function to parse time into minutes and seconds
def parse_time(time_str):
    minutes, seconds = time_str.split(':')
    return int(minutes), float(seconds)

# Parse Time column into minutes and seconds
df[['Minutes', 'Seconds']] = df['Time'].apply(lambda x: pd.Series(parse_time(x)))

# Reverse the dataset to make transition checks easier
data = df[::-1].reset_index(drop=True)

# Initialize transition flag
flags = []

# Iterate through rows to identify transitions
for i in range(len(df)):
    if i > 0:
        prev_minutes, prev_seconds = df.loc[i - 1, ['Minutes', 'Seconds']]
        curr_minutes, curr_seconds = df.loc[i, ['Minutes', 'Seconds']]
        
        # # Check for transition from 59:58.x to 00:00.x
        # if prev_minutes == 0 and prev_seconds <= 1 and curr_minutes == 59 and curr_seconds >= 58:
        if prev_minutes == 59 and prev_seconds >= 58 and curr_minutes == 0 and curr_seconds <= 1:    
            flags.append(1)  # Mark transition with a flag
        else:
            flags.append(0)
    else:
        flags.append(0)  # First row, no transition

# Add Flag column to the DataFrame
df['Transition_Flag'] = flags


indx_lst = df[df['Transition_Flag']==1].index.to_list()
# Add the starting and ending indices for the full range
start_indices = [0] + [i + 1 for i in indx_lst]
end_indices = indx_lst + [None]  # None to indicate the end of the range

# Generate index ranges
index_ranges = [(start, end) for start, end in zip(start_indices, end_indices)]

# Print the ranges
cnt=0
for start, end in index_ranges:
    print(f"Range: [{start}:{end}]")
    # print('0'+str(cnt)+":"+df['Time'])
    df.loc[start:end,'Time']='0'+str(cnt)+":"+df['Time']
    cnt+=1

df['DateTime']=pd.to_datetime(df['Date']+" "+df['Time'])#,format='%m/%d/%Y %H:%M:%S.%f')
df['month'] =df['DateTime'].dt.month
df['year'] =df['DateTime'].dt.year
df['hour']=df['DateTime'].dt.hour

# selecting the required column for moving for problem solving
df = df[['DateTime', 'month', 'year', 'hour', 'Minutes', 'Seconds','Defect Rate']]
#Removing the % sign for futher calculation
df['Defect_Rate']=df['Defect Rate'].apply(lambda x:x.split("%")[0]).astype(int)/100

df=df.drop(columns=['Defect Rate'],axis=1)
# Out:
# Range: [0:2399]
# Range: [2400:6180]
# Range: [6181:9947]
# Range: [9948:None]

# %%
df.head()
# Out:
#                  DateTime  month  year  hour  Minutes  Seconds  Defect_Rate
# 0 2024-08-29 00:23:02.700      8  2024     0     23.0      2.7         0.10
# 1 2024-08-29 00:23:03.600      8  2024     0     23.0      3.6         0.06
# 2 2024-08-29 00:23:04.500      8  2024     0     23.0      4.5         0.12
# 3 2024-08-29 00:23:05.400      8  2024     0     23.0      5.4         0.15
# 4 2024-08-29 00:23:06.300      8  2024     0     23.0      6.3         0.10

# %%
def drop_columns(df):
    temp1 = df.nunique().reset_index()
    temp1.columns = ['columns','cnt']
    drop_list = temp1.loc[temp1['cnt']==1,'columns'].to_list()  # selecting the columns with low variance
    drop_list.append("Time")
    df = df.drop(columns=drop_list,axis=1)
    df.sort_values("MeasurementCount",ascending=True,inplace=True)
    return df

# %%
df_step1_terminal = drop_columns(df_step1_terminal)
df_step1_resin = drop_columns(df_step1_resin)
df_step2_wind_wire = drop_columns(df_step2_wind_wire)
df_step3_peel_wire = drop_columns(df_step3_peel_wire)
temp_date_time = df_step4_check_alignment[['DateTime',"Time"]]
df_step4_check_alignment = drop_columns(df_step4_check_alignment)

df_step4_check_alignment = pd.concat([temp_date_time,df_step4_check_alignment],axis=1)

# %%
combined_df = pd.concat([df_step1_terminal,df_step1_resin,df_step2_wind_wire,df_step3_peel_wire,df_step4_check_alignment],axis=1)

# %%
preprocess_data =combined_df.reset_index(drop=True)

# %%
# Function to parse time into minutes and seconds
def parse_time(time_str):
    minutes, seconds = time_str.split(':')
    return int(minutes), float(seconds)

# Parse Time column into minutes and seconds
preprocess_data[['Minutes', 'Seconds']] = preprocess_data['Time'].apply(lambda x: pd.Series(parse_time(x)))

# Initialize transition flag
flags = []

# Iterate through rows to identify transitions
for i in range(len(data)):
    if i > 0:
        prev_minutes, prev_seconds = preprocess_data.loc[i - 1, ['Minutes', 'Seconds']]
        curr_minutes, curr_seconds = preprocess_data.loc[i, ['Minutes', 'Seconds']]
        
        # Check for transition from 59:58.x to 00:00.x
        if prev_minutes == 59 and prev_seconds >= 58 and curr_minutes == 0 and curr_seconds <= 1:
            flags.append(1)  # Mark transition with a flag
        else:
            flags.append(0)
    else:
        flags.append(0)  # First row, no transition

# Add Transition_Flag column to the DataFrame
preprocess_data['Transition_Flag'] = flags

# Drop unnecessary columns if needed
preprocess_data = preprocess_data.drop(columns=['Minutes', 'Seconds'])

# %%
indx_lst_pre = preprocess_data[preprocess_data['Transition_Flag']==1].index.to_list()
indx_lst_pre
# Add the starting and ending indices for the full range
start_indices = [0] + [i + 1 for i in indx_lst_pre]
end_indices = indx_lst_pre + [None]  # None to indicate the end of the range

# Generate index ranges
index_ranges = [(start, end) for start, end in zip(start_indices, end_indices)]

# Print the ranges
cnt=0
for start, end in index_ranges:
    print(f"Range: [{start}:{end}]")
    # print('0'+str(cnt)+":"+df['Time'])
    preprocess_data.loc[start:end,'Time']='0'+str(cnt)+":"+preprocess_data['Time']
    cnt+=1
# Out:
# Range: [0:2120]
# Range: [2121:6059]
# Range: [6060:None]

# %%
preprocess_data['DateTime']=pd.to_datetime(preprocess_data['DateTime']+" "+preprocess_data['Time'])#,format='%m/%d/%Y %H:%M:%S.%f')
preprocess_data['month'] =preprocess_data['DateTime'].dt.month
preprocess_data['year'] =preprocess_data['DateTime'].dt.year
preprocess_data['hour']=preprocess_data['DateTime'].dt.hour
preprocess_data = preprocess_data.drop(columns=['Time'],axis=1)

# %%
preprocess_data.head()
# Out:
#    MeasurementCount OverallJudgment  Trg1PitchUpper  Trg1PitchLower  \
# 0            977767              OK         3.03393         3.03893
# 1            977768              OK         3.03715         3.04490
# 2            977769              OK         3.03732         3.02259
# 3            977770              OK         3.03034         3.03683
# 4            977771              OK         3.03144         3.03615
#
#    Trg1PitchLeft  Trg1PitchRight  Trg1TerminalThetaCheckArea1  \
# 0        1.87532         1.85283                            3
# 1        1.87389         1.86485                            0
# 2        1.88290         1.86939                           10
# 3        1.87533         1.86221                            0
# 4        1.86934         1.86785                            0
#
#    Trg1TerminalThetaCheckArea2  Trg1TerminalThetaCheckArea3  \
# 0                           20                            7
# 1                           44                           13
# 2                           22                            6
# 3                           50                            0
# 4                           11                            6
#
#    Trg1TerminalThetaCheckArea4  ...  LowerRight_FittingSearchHeight  \
# 0                           39  ...                          0.0741
# 1                           53  ...                          0.0855
# 2                           14  ...                          0.0798
# 3                           45  ...                          0.0855
# 4                           30  ...                          0.0684
#
#    LowerRight_CameraCenter_IrradiationDistanceX  \
# 0                                       1.25951
# 1                                       1.25666
# 2                                       1.27965
# 3                                       1.26540
# 4                                       1.28535
#
#    LowerRight_CameraCenter_IrradiationDistanceY  \
# 0                                        2.2686
# 1                                        2.2743
# 2                                        2.2743
# 3                                        2.2857
# 4                                        2.2686
#
#    LowerRight_ProductCenter_IrradiationDistanceX  \
# 0                                        2.28610
# 1                                        2.29221
# 2                                        2.29267
# 3                                        2.30449
# 4                                        2.28765
#
#    LowerRight_ProductCenter_IrradiationDistanceY  InspectionExecutionID  \
# 0                                        1.19866                      1
# 1                                        1.19166                      1
# 2                                        1.19854                      1
# 3                                        1.18700                      1
# 4                                        1.18424                      1
#
#    Transition_Flag  month  year  hour
# 0                0      8  2024     0
# 1                0      8  2024     0
# 2                0      8  2024     0
# 3                0      8  2024     0
# 4                0      8  2024     0
#
# [5 rows x 118 columns]

# %%
preprocess_data = preprocess_data.drop(columns=['Time'],axis=1)

# %%
import os

# %%
os.makedirs("../preprocessed_data/")

# %%
df.to_csv("../preprocessed_data/defect_rate_preprocessed.csv",index=False)
preprocess_data.to_csv("../preprocessed_data/combined_processed_data.csv",index=False)
